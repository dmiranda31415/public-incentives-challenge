# %%
import pandas as pd

# 1. Ler os ficheiros
df_companies = pd.read_csv("C:/Users/dmira/OneDrive/Ambiente de Trabalho/public_incentives/data/companies.csv" , low_memory=False)
df_incentives = pd.read_csv("C:/Users/dmira/OneDrive/Ambiente de Trabalho/public_incentives/data/incentives.csv" , low_memory=False)

# 2. Ver dimensões
print("Companies:", companies.shape)
print("Incentives:", incentives.shape)

# 3. Primeiras linhas
display(companies.head())
display(incentives.head())

# 4. Colunas
print("\nCompanies columns:\n", list(companies.columns))
print("\nIncentives columns:\n", list(incentives.columns))

# 5. Valores nulos
print("\nMissing values (companies):")
display(companies.isnull().sum().sort_values(ascending=False).head(15))

print("\nMissing values (incentives):")
display(incentives.isnull().sum().sort_values(ascending=False).head(15))

# 6. Duplicados
print("\nDuplicados companies:", companies.duplicated().sum())
print("Duplicados incentives:", incentives.duplicated().sum())
# Out:
# Companies: (250000, 4)
# Incentives: (500, 18)
#                                     company_name  \
# 0           DANIJO - INDÚSTRIA DE CONFECÇÃO, LDA
# 1  TAXIGÁS - COMÉRCIO E DISTRIBUIÇÃO DE GÁS, LDA
# 2                             BLKW BUSINESS, LDA
# 3                       BÚSSOLA SEM LIMITES, LDA
# 4                ABSOLUTPARADOX, UNIPESSOAL, LDA
#
#                                  cae_primary_label  \
# 0  Mass production of other garments, unspecified.
# 1                  Wholesale of petroleum products
# 2                  Non-specialised wholesale trade
# 3                          Traditional restaurants
# 4            Buying and selling of own real estate
#
#                             trade_description_native        website
# 0  Confeção de vestuário em série, e de artigos e...  www.danijo.pt
# 1  Comércio a retalho de combustíveis para uso do...            NaN
# 2  Consultoria para os negócios e gestão. Importa...     www.bwv.pt
# ...

# %%
# Normalizar Companies
companies_clean = companies.rename(columns={
    "company_name": "name",
    "cae_primary_label": "nace_code",
    "trade_description_native": "sector",
    "website": "website"
})[["name", "nace_code", "sector", "website"]]

# Normalizar Incentives
incentives_clean = incentives.rename(columns={
    "incentive_project_id": "incentive_id",
    "title": "title",
    "ai_description": "description",
    "eligibility_criteria": "eligibility_text",
    "total_budget": "budget",
    "date_start": "start_date",
    "date_end": "end_date",
    "incentive_program": "program"
})[["incentive_id", "title", "description", "eligibility_text", "budget", "start_date", "end_date", "program"]]

# Verificar amostra
display(companies_clean.head())
display(incentives_clean.head())

# Guardar limpos
companies_clean.to_csv("C:/Users/dmira/OneDrive/Ambiente de Trabalho/public_incentives/data/companies_clean.csv", index=False)
incentives_clean.to_csv("C:/Users/dmira/OneDrive/Ambiente de Trabalho/public_incentives/data/incentives_clean.csv", index=False)

print("✅ Dados normalizados e guardados em data/companies_clean.csv e data/incentives_clean.csv")
# Out:
#                                             name  \
# 0           DANIJO - INDÚSTRIA DE CONFECÇÃO, LDA
# 1  TAXIGÁS - COMÉRCIO E DISTRIBUIÇÃO DE GÁS, LDA
# 2                             BLKW BUSINESS, LDA
# 3                       BÚSSOLA SEM LIMITES, LDA
# 4                ABSOLUTPARADOX, UNIPESSOAL, LDA
#
#                                          nace_code  \
# 0  Mass production of other garments, unspecified.
# 1                  Wholesale of petroleum products
# 2                  Non-specialised wholesale trade
# 3                          Traditional restaurants
# 4            Buying and selling of own real estate
#
#                                               sector        website
# 0  Confeção de vestuário em série, e de artigos e...  www.danijo.pt
# 1  Comércio a retalho de combustíveis para uso do...            NaN
# 2  Consultoria para os negócios e gestão. Importa...     www.bwv.pt
# 3  Exploração de bares e restauração. Exploração ...            NaN
# ...

# %%
from sqlalchemy import create_engine
engine = create_engine("postgresql://postgres:Semprea100%@localhost/public_incentives")

# %%
df_companies.to_sql('companies', engine, if_exists='replace', index=False)
df_incentives.to_sql('incentives', engine, if_exists='replace', index=False)
# Out:
# 500

# %%
DATABASE_URL=postgresql://postgres:Semprea100%@host:5432/public_incentives
# Out:
#   Cell In[18], line 1
#     DATABASE_URL=postgresql://postgres:Semprea100%@host:5432/public_incentives
#                            ^
# SyntaxError: invalid syntax
